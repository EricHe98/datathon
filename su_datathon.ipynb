# %%
import pandas as pd

# census = pd.read_csv("census.csv", sep = ',', error_bad_lines=False)
# content = pd.read_csv("content.csv", sep = ',', error_bad_lines=False)
pageview = pd.read_csv("pageview.csv", sep = ',', error_bad_lines=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-2505de91af4d> in <module>
#       3 # census = pd.read_csv("census.csv", sep = ',', error_bad_lines=False)
#       4 # content = pd.read_csv("content.csv", sep = ',', error_bad_lines=False)
# ----> 5 pageview = pd.read_csv("pageview.csv", sep = ',', error_bad_lines=False)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'pageview.csv' does not exist: b'pageview.csv'

# %%
pageview['CENSUS_KEY'].isnull().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt

pageview['URL_PATH_BROKEN'] = [x.split("/") for x in pageview['URL_PATH']]
pageview['LANGUAGE'] = [x[1] for x in pageview['URL_PATH_BROKEN']]

result=[]
for row in pageview['URL_PATH_BROKEN']:
    try:
        result.append(row[2])
    except:
        result.append(" ")
        pass

pageview['CATEGORY'] = result
pageview
# Out:
#          ROW_NUM                                            USER_ID  \
# 0        2750000  5150228a-ad62-4a14-9169-79e7979e1a5e_46ac5dea-...
# 1        2749999  5150228a-ad62-4a14-9169-79e7979e1a5e_f13c5ba7-...
# 2        2749998  5150228a-ad62-4a14-9169-79e7979e1a5e_22e91c69-...
# 3        2749997  5150228a-ad62-4a14-9169-79e7979e1a5e_5fe37e08-...
# 4        2749996  5150228a-ad62-4a14-9169-79e7979e1a5e_f106f359-...
# 5        2749995  5150228a-ad62-4a14-9169-79e7979e1a5e_54bec514-...
# 6        2749994  5150228a-ad62-4a14-9169-79e7979e1a5e_b6504452-...
# 7        2749993  5150228a-ad62-4a14-9169-79e7979e1a5e_22e91c69-...
# 8        2749992  5150228a-ad62-4a14-9169-79e7979e1a5e_17d751df-...
# 9        2749991  5150228a-ad62-4a14-9169-79e7979e1a5e_cac5b16d-...
# 10       2749990  5150228a-ad62-4a14-9169-79e7979e1a5e_a9a4408c-...
# 11       2749989  5150228a-ad62-4a14-9169-79e7979e1a5e_b8a0e34d-...
# 12       2749988  5150228a-ad62-4a14-9169-79e7979e1a5e_c21e3060-...
# 13       2749987  5150228a-ad62-4a14-9169-79e7979e1a5e_ff7d79b5-...
# 14       2749986  5150228a-ad62-4a14-9169-79e7979e1a5e_22e91c69-...
# 15       2749985  5150228a-ad62-4a14-9169-79e7979e1a5e_0fdf0356-...
# 16       2749984  5150228a-ad62-4a14-9169-79e7979e1a5e_3c89432d-...
# 17       2749983  5150228a-ad62-4a14-9169-79e7979e1a5e_e7347422-...
# 18       2749982  5150228a-ad62-4a14-9169-79e7979e1a5e_9b3bf000-...
# 19       2749981  5150228a-ad62-4a14-9169-79e7979e1a5e_5db3569f-...
# 20       2749980  5150228a-ad62-4a14-9169-79e7979e1a5e_47ecbc8c-...
# 21       2749979  5150228a-ad62-4a14-9169-79e7979e1a5e_22e91c69-...
# 22       2749978  5150228a-ad62-4a14-9169-79e7979e1a5e_26b8067d-...
# 23       2749977  5150228a-ad62-4a14-9169-79e7979e1a5e_148b1308-...
# 24       2749976  5150228a-ad62-4a14-9169-79e7979e1a5e_7e7827e8-...
# 25       2749975  5150228a-ad62-4a14-9169-79e7979e1a5e_58191c65-...
# 26       2749974  5150228a-ad62-4a14-9169-79e7979e1a5e_f16413fd-...
# 8        /en/learning-attention-issues/child-learning-d...
# 9        /en/learning-attention-issues/child-learning-d...
# 10               /en/tools/through-your-childs-eyes/player
# 11                                                     /en
# 12               /en/tools/through-your-childs-eyes/player
# 13       /en/community-events/experts-live-chats-webina...
# 14       /en/learning-attention-issues/treatments-appro...
# 15                  /en/friends-feelings/common-challenges
# 16       /en/school-learning/your-childs-rights/basics-...
# 17       /es-mx/learning-attention-issues/treatments-ap...
# 18       /en/friends-feelings/common-challenges/bullyin...
# 19       /en/community-events/experts-live-chats-webina...
# 20       /en/learning-attention-issues/understanding-ch...
# 21       /en/learning-attention-issues/treatments-appro...
# 22       /en/friends-feelings/common-challenges/picking...
# 23       /en/learning-attention-issues/child-learning-d...
# 24       /en/school-learning/partnering-with-childs-sch...
# 25       /en/learning-attention-issues/signs-symptoms/d...
# 26               /en/tools/through-your-childs-eyes/player
# 27       /en/learning-attention-issues/child-learning-d...
# 28       /en/learning-attention-issues/child-learning-d...
# 29       /en/friends-feelings/empowering-your-child/sel...
# ...                                                    ...
# 2749969  /es-mx/school-learning/your-childs-rights/eval...
# 2749970  /en/school-learning/assistive-technology/findi...
# 2749971                      /en/learning-attention-issues
# 2749972  /en/learning-attention-issues/child-learning-d...
# 2749973  /en/friends-feelings/empowering-your-child/bui...
# 2749974  /es-mx/friends-feelings/managing-feelings/stre...
# 2749975  /en/school-learning/your-childs-rights/basics-...
# 2749976  /en/friends-feelings/managing-feelings/anger-f...
# 2749977  /en/learning-attention-issues/child-learning-d...
# 2749978                 /en/tools/through-your-childs-eyes
# 2749979          /en/tools/through-your-childs-eyes/player
# 2749980  /es-mx/family/taking-care-of-yourself/dealing-...
# 2749981                   /en/recommendations/just-for-you
# 2749982  /en/school-learning/choosing-starting-school/b...
# 2749983  /en/learning-attention-issues/child-learning-d...
# 2749984  /en/school-learning/learning-at-home/encouragi...
# 2749985  /en/learning-attention-issues/child-learning-d...
# 2749986  /en/school-learning/choosing-starting-school/f...
# 2749987  /en/learning-attention-issues/child-learning-d...
# 2749988  /en/learning-attention-issues/child-learning-d...
# 2749989  /es-mx/learning-attention-issues/child-learnin...
# 2749990  /en/school-learning/evaluations/evaluation-bas...
# 2749991  /en/learning-attention-issues/child-learning-d...
# 2749992          /en/tools/through-your-childs-eyes/player
# 2749993  /en/learning-attention-issues/child-learning-d...
# 2749994  /en/school-learning/evaluations/evaluation-bas...
# 2749995  /en/community-events/blogs/adhd-news/2018/10/3...
# 2749996  /en/school-learning/special-services/special-e...
# 2749997  /en/friends-feelings/managing-feelings/stress-...
# 2749998  /en/tools/parenting-coach/articles/come-up-wit...
#
#                                        CENSUS_KEY  \
# 0        58a9cf6a144233ad9c286a2533872b2c3a9c1998
# 1        79cfc7a3c90fa4fc002ec3978716f823078afc23
# 2        bc2e78278714e173c09535d7d0260e6299b9bd09
# 3        07e692d47d057cb1d0409cf6e701f9be5cda3e36
# 4        85e32c288526fc2b24b0db665254c7f2b433a14e
# 5        e9876bf61893ac62113e3ff3e516783c6810595a
# 6        58a9cf6a144233ad9c286a2533872b2c3a9c1998
# 7        bc2e78278714e173c09535d7d0260e6299b9bd09
# 8        58a9cf6a144233ad9c286a2533872b2c3a9c1998
# 2        [, en, learning-attention-issues, child-learni...       en
# 3        [, en, learning-attention-issues, child-learni...       en
# 4        [, en, learning-attention-issues, child-learni...       en
# 5        [, en, school-learning, evaluations, evaluatio...       en
# 6        [, en, learning-attention-issues, child-learni...       en
# 7        [, en, learning-attention-issues, child-learni...       en
# 8        [, en, learning-attention-issues, child-learni...       en
# 9        [, en, learning-attention-issues, child-learni...       en
# 10         [, en, tools, through-your-childs-eyes, player]       en
# 11                                                  [, en]       en
# 12         [, en, tools, through-your-childs-eyes, player]       en
# 13       [, en, community-events, experts-live-chats-we...       en
# 14       [, en, learning-attention-issues, treatments-a...       en
# 15             [, en, friends-feelings, common-challenges]       en
# 16       [, en, school-learning, your-childs-rights, ba...       en
# 17       [, es-mx, learning-attention-issues, treatment...    es-mx
# 18       [, en, friends-feelings, common-challenges, bu...       en
# 19       [, en, community-events, experts-live-chats-we...       en
# 20       [, en, learning-attention-issues, understandin...       en
# 21       [, en, learning-attention-issues, treatments-a...       en
# 22       [, en, friends-feelings, common-challenges, pi...       en
# 23       [, en, learning-attention-issues, child-learni...       en
# 24       [, en, school-learning, partnering-with-childs...       en
# 25       [, en, learning-attention-issues, signs-sympto...       en
# 26         [, en, tools, through-your-childs-eyes, player]       en
# 27       [, en, learning-attention-issues, child-learni...       en
# 28       [, en, learning-attention-issues, child-learni...       en
# 29       [, en, friends-feelings, empowering-your-child...       en
# ...                                                    ...      ...
# 2749969  [, es-mx, school-learning, your-childs-rights,...    es-mx
# 2749970  [, en, school-learning, assistive-technology, ...       en
# 2749971                  [, en, learning-attention-issues]       en
# 2749972  [, en, learning-attention-issues, child-learni...       en
# 2749973  [, en, friends-feelings, empowering-your-child...       en
# 2749974  [, es-mx, friends-feelings, managing-feelings,...    es-mx
# 2749975  [, en, school-learning, your-childs-rights, ba...       en
# 2749976  [, en, friends-feelings, managing-feelings, an...       en
# 2749977  [, en, learning-attention-issues, child-learni...       en
# 2749978            [, en, tools, through-your-childs-eyes]       en
# 2749979    [, en, tools, through-your-childs-eyes, player]       en
# 2749980  [, es-mx, family, taking-care-of-yourself, dea...    es-mx
# 2749981              [, en, recommendations, just-for-you]       en
# 2749982  [, en, school-learning, choosing-starting-scho...       en
# 2749983  [, en, learning-attention-issues, child-learni...       en
# 2749984  [, en, school-learning, learning-at-home, enco...       en
# 2749985  [, en, learning-attention-issues, child-learni...       en
# 2749986  [, en, school-learning, choosing-starting-scho...       en
# 2749987  [, en, learning-attention-issues, child-learni...       en
# 2749988  [, en, learning-attention-issues, child-learni...       en
# 2749989  [, es-mx, learning-attention-issues, child-lea...    es-mx
# 2749990  [, en, school-learning, evaluations, evaluatio...       en
# 2749991  [, en, learning-attention-issues, child-learni...       en
# 2749992    [, en, tools, through-your-childs-eyes, player]       en
# 2749993  [, en, learning-attention-issues, child-learni...       en
# 2749994  [, en, school-learning, evaluations, evaluatio...       en
# 2749995  [, en, community-events, blogs, adhd-news, 201...       en
# 2749996  [, en, school-learning, special-services, spec...       en
# 2749997  [, en, friends-feelings, managing-feelings, st...       en
# 2749998  [, en, tools, parenting-coach, articles, come-...       en
#
#                           CATEGORY
# 0                 friends-feelings
# 1                  school-learning
# 2        learning-attention-issues
# 3        learning-attention-issues
# 4        learning-attention-issues
# 5                  school-learning
# 6        learning-attention-issues
# 7        learning-attention-issues
# 8        learning-attention-issues
# 9        learning-attention-issues
# 10                           tools
# 11
# 12                           tools
# 13                community-events
# 14       learning-attention-issues
# 15                friends-feelings
# 16                 school-learning
# 17       learning-attention-issues
# 18                friends-feelings
# 19                community-events
# 20       learning-attention-issues
# 21       learning-attention-issues
# 22                friends-feelings
# 23       learning-attention-issues
# 24                 school-learning
# 25       learning-attention-issues
# 26                           tools
# 27       learning-attention-issues
# 28       learning-attention-issues
# 29                friends-feelings
# ...                            ...
# 2749969            school-learning
# 2749970            school-learning
# 2749971  learning-attention-issues
# 2749972  learning-attention-issues
# 2749973           friends-feelings
# 2749974           friends-feelings
# 2749975            school-learning
# 2749976           friends-feelings
# 2749977  learning-attention-issues
# 2749978                      tools
# 2749979                      tools
# 2749980                     family
# 2749981            recommendations
# 2749982            school-learning
# 2749983  learning-attention-issues
# 2749984            school-learning
# 2749985  learning-attention-issues
# 2749986            school-learning
# 2749987  learning-attention-issues
# 2749988  learning-attention-issues
# 2749989  learning-attention-issues
# 2749990            school-learning
# 2749991  learning-attention-issues
# 2749992                      tools
# 2749993  learning-attention-issues
# 2749994            school-learning
# 2749995           community-events
# 2749996            school-learning
# 2749997           friends-feelings
# 2749998                      tools
#
# [2749999 rows x 7 columns]

# %%
import pandas as pd
from recommendation import AbstractRecommender

class ExampleRecommender(AbstractRecommender):
    def __init__(self):
        self.last_page_viewed = {}
        self.user = {}
        self.censusinfo = {}
        self.embed_article = {}

    def observe(self, user_interaction):
        user_id = user_interaction["user_id"]
        url_path = user_interaction["url_path"]
        census_key = user_interaction["census_key"]
        
        self.last_page_viewed[user_id] = url_path
        if user_id in self.user.keys(): self.user[user_id] += 1
        else: self.user[user_id] = 1
        self.censusinfo[user_id] = census_key
#         self.embed_article[] = 

    def recommend(self, user_id, n):
        try:
            return n * [self.last_page_viewed[user_id]]
        except KeyError:
            return n * ["/en"]

# %%
if __name__ == "__main__":
    user_interactions = pageview[:10]
#     user_interactions = pd.DataFrame(
#         dict(
#             row_num=range(6),
#             user_id=["a", "b", "c", "a", "b", "b"],
#             url_path=["/en/z", "/en/x", "/en", "/en/x", "/en/y", "/en"],
#             census_key=["p", "q", "r", "p", "q", "q"],
#         )
#     )    

    print("Test user interaction data:")
    print(user_interactions)
    print()

    n = 3
    print(f"Example site-visit and recommendation sequence:")
    user_lastpage_dict = {}
    recommender = ExampleRecommender()
    for i, (_, s) in enumerate(user_interactions.iterrows()):
        recommendations = recommender.recommend(s["user_id"], n)
        current_page = (
            user_lastpage_dict.get(s["user_id"])
            if s["user_id"] in user_lastpage_dict
            else "/en"
        )
        print(f"{i + 1}. While user {s['user_id']} views {current_page}:")
        print(f"   - We recommend {recommendations}.")
        print(f"   - User then visits {s['url_path']} at time {s['row_num']}.")
        recommender.observe(s)
        user_lastpage_dict[s["user_id"]] = s["url_path"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-479b7b6bdc3f> in <module>
#       1 if __name__ == "__main__":
# ----> 2     user_interactions = pageview[:10]
#       3 #     user_interactions = pd.DataFrame(
#       4 #         dict(
#       5 #             row_num=range(6),
#
# NameError: name 'pageview' is not defined
